# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Statements" data-toc-modified-id="Import-Statements-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Statements</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span></li><li><span><a href="#Create-df_rape" data-toc-modified-id="Create-df_rape-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Create df_rape</a></span></li><li><span><a href="#Data-Cleanup" data-toc-modified-id="Data-Cleanup-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Cleanup</a></span></li><li><span><a href="#Creation-of-datetime-column" data-toc-modified-id="Creation-of-datetime-column-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Creation of datetime column</a></span></li><li><span><a href="#Time-Investigation" data-toc-modified-id="Time-Investigation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Time Investigation</a></span></li></ul></div>

# %% [markdown]
# # Import Statements

# %%
# Note: the 538 article:
# https://projects.fivethirtyeight.com/sexual-assault-victims/

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math
import seaborn as sns
import sklearn
from sklearn import linear_model
from sklearn import preprocessing
# %matplotlib inline
sns.set_style('white')

# %%
# Data from https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i
df = pd.read_csv('NYPD_Complaint_Data_Historic.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO              ...                      44.0
# ...

# %%
df
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         101109527   12/31/2015     23:45:00          NaN          NaN
# 1         153401121   12/31/2015     23:36:00          NaN          NaN
# 2         569369778   12/31/2015     23:30:00          NaN          NaN
# 3         968417082   12/31/2015     23:30:00          NaN          NaN
# 4         641637920   12/31/2015     23:25:00   12/31/2015     23:30:00
# 5         365661343   12/31/2015     23:18:00   12/31/2015     23:25:00
# 6         608231454   12/31/2015     23:15:00          NaN          NaN
# 7         265023856   12/31/2015     23:15:00   12/31/2015     23:15:00
# 8         989238731   12/31/2015     23:15:00   12/31/2015     23:30:00
# 9         415095955   12/31/2015     23:10:00   12/31/2015     23:10:00
# 10        731283092   12/31/2015     23:05:00   12/31/2015     23:15:00
# 11        178090167   12/31/2015     23:00:00   12/31/2015     23:05:00
# ...

# %%
df.dtypes
# Out:
# CMPLNT_NUM             int64
# CMPLNT_FR_DT          object
# CMPLNT_FR_TM          object
# CMPLNT_TO_DT          object
# CMPLNT_TO_TM          object
# RPT_DT                object
# KY_CD                  int64
# OFNS_DESC             object
# PD_CD                float64
# PD_DESC               object
# CRM_ATPT_CPTD_CD      object
# LAW_CAT_CD            object
# JURIS_DESC            object
# BORO_NM               object
# ADDR_PCT_CD          float64
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# PARKS_NM              object
# HADEVELOPT            object
# X_COORD_CD           float64
# Y_COORD_CD           float64
# Latitude             float64
# Longitude            float64
# Lat_Lon               object
# dtype: object

# %%
df['OFNS_DESC'].value_counts()
# Out:
# PETIT LARCENY                           987326
# HARRASSMENT 2                           736479
# ASSAULT 3 & RELATED OFFENSES            625624
# CRIMINAL MISCHIEF & RELATED OF          603977
# GRAND LARCENY                           516544
# DANGEROUS DRUGS                         392992
# OFF. AGNST PUB ORD SENSBLTY &           327716
# ROBBERY                                 228220
# FELONY ASSAULT                          224921
# BURGLARY                                216439
# MISCELLANEOUS PENAL LAW                 145888
# DANGEROUS WEAPONS                       143395
# OFFENSES AGAINST PUBLIC ADMINI          117062
# GRAND LARCENY OF MOTOR VEHICLE          114071
# INTOXICATED & IMPAIRED DRIVING           85349
# CRIMINAL TRESPASS                        74083
# VEHICLE AND TRAFFIC LAWS                 72173
# SEX CRIMES                               68020
# THEFT-FRAUD                              66184
# FORGERY                                  61024
# ...

# %%
# Identifying attempted rape vs completed rape
df.loc[df['OFNS_DESC'] == 'RAPE', 'CRM_ATPT_CPTD_CD'].value_counts()
# Out:
# COMPLETED    14843
# ATTEMPTED     1830
# Name: CRM_ATPT_CPTD_CD, dtype: int64

# %% [markdown]
# # Create df_rape

# %%
df_rape = df.loc[df['OFNS_DESC'] == 'RAPE']

# %%
df_rape.shape
# Out:
# (16673, 24)

# %%
# The outcome variable, rape completed vs attempted
df_rape['CRM_ATPT_CPTD_CD'].value_counts()
# Out:
# COMPLETED    14843
# ATTEMPTED     1830
# Name: CRM_ATPT_CPTD_CD, dtype: int64

# %%
df_rape.isnull().sum()
# Out:
# CMPLNT_NUM               0
# CMPLNT_FR_DT             1
# CMPLNT_FR_TM             0
# CMPLNT_TO_DT          3604
# CMPLNT_TO_TM          3598
# RPT_DT                   0
# KY_CD                    0
# OFNS_DESC                0
# PD_CD                    0
# PD_DESC                  0
# CRM_ATPT_CPTD_CD         0
# LAW_CAT_CD               0
# JURIS_DESC               0
# BORO_NM                  4
# ADDR_PCT_CD              4
# LOC_OF_OCCUR_DESC     1555
# PREM_TYP_DESC           63
# PARKS_NM             16583
# HADEVELOPT           15538
# X_COORD_CD           16673
# Y_COORD_CD           16673
# Latitude             16673
# Longitude            16673
# Lat_Lon              16673
# dtype: int64

# %%
# NULL VALUES TO WATCH OUT FOR

# %%
(df_rape['CMPLNT_FR_TM'] == '24:00:00').value_counts(sort = True)
# Out:
# False    16654
# True        19
# Name: CMPLNT_FR_TM, dtype: int64

# %%
(df_rape['CMPLNT_TO_TM'] == '24:00:00').value_counts(sort = True)
# Out:
# False    16614
# True        59
# Name: CMPLNT_TO_TM, dtype: int64

# %%
df_rape.loc[df_rape['CMPLNT_FR_DT'].isna()]
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1008394   155379861          NaN     06:00:00   12/02/2013     06:30:00
#
#              RPT_DT  KY_CD OFNS_DESC  PD_CD         PD_DESC   ...     \
# 1008394  12/02/2013    104      RAPE  159.0  RAPE 1,ATTEMPT   ...
#
#         ADDR_PCT_CD LOC_OF_OCCUR_DESC           PREM_TYP_DESC PARKS_NM  \
# 1008394        90.0            INSIDE  RESIDENCE - APT. HOUSE      NaN
#
#          HADEVELOPT X_COORD_CD Y_COORD_CD Latitude Longitude  Lat_Lon
# 1008394         NaN        NaN        NaN      NaN       NaN      NaN
#
# [1 rows x 24 columns]

# %% [markdown]
# # Data Cleanup

# %%
# In situations where the From Date is Null, change to to date

# %%
# Get rid of a troublesome na
df_rape.loc[df_rape['CMPLNT_FR_DT'].isna(), 'CMPLNT_FR_DT'] = df_rape.loc[df_rape['CMPLNT_FR_DT'].isna(), 'CMPLNT_TO_DT']
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_rape.loc[df_rape['CMPLNT_FR_DT'].isna()]
# Out:
# Empty DataFrame
# Columns: [CMPLNT_NUM, CMPLNT_FR_DT, CMPLNT_FR_TM, CMPLNT_TO_DT, CMPLNT_TO_TM, RPT_DT, KY_CD, OFNS_DESC, PD_CD, PD_DESC, CRM_ATPT_CPTD_CD, LAW_CAT_CD, JURIS_DESC, BORO_NM, ADDR_PCT_CD, LOC_OF_OCCUR_DESC, PREM_TYP_DESC, PARKS_NM, HADEVELOPT, X_COORD_CD, Y_COORD_CD, Latitude, Longitude, Lat_Lon]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Get rid of troublesome 24:00:00 values in 'From Time'
df_rape.loc[df_rape['CMPLNT_FR_TM'] == '24:00:00', 'CMPLNT_FR_TM'] = '23:59:59'
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Get rid of troublesome 24:00:00 values in 'To Time'
df_rape.loc[df_rape['CMPLNT_TO_TM'] == '24:00:00', 'CMPLNT_TO_TM'] = '23:59:59'
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Check cells
df_rape.sort_values(by='CMPLNT_FR_TM', ascending=False)
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 3466499   829061498   06/01/2002     23:59:59   01/06/2009     15:35:00
# 3894448   268184195   03/30/2008     23:59:59          NaN          NaN
# 3659304   674449658   11/28/2007     23:59:59          NaN          NaN
# 3838102   937145860   10/12/2007     23:59:59          NaN          NaN
# 3379603   282308644   01/01/2004     23:59:59   12/31/2004     23:59:00
# 3601184   357409136   01/01/2007     23:59:59   10/13/2008     23:59:59
# 3441876   965083518   11/01/2008     23:59:59   11/15/2008     23:59:59
# 3179713   678406708   04/01/2004     23:59:59   06/01/2005     23:59:00
# 4153011   833029701   08/29/2007     23:59:59          NaN          NaN
# 4011256   266934295   10/31/2007     23:59:59          NaN          NaN
# 3448223   742908077   05/01/2008     23:59:59   01/19/2009     23:59:00
# 3841346   635227790   08/01/2006     23:59:59   09/30/2006     23:59:59
# ...

# %%
df_rape.sort_values(by='CMPLNT_TO_TM', ascending=False)
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 3841350   618252524   05/24/2006     09:00:00   01/01/2008     23:59:59
# 3439084   763217678   09/01/2008     23:59:59   01/12/2009     23:59:59
# 3440507   203276462   01/10/2009     00:01:00   01/10/2009     23:59:59
# 3656480   606699261   01/01/2005     15:00:00   04/30/2008     23:59:59
# 4201880   155768460   07/07/2007     20:00:00   07/08/2007     23:59:59
# 3441876   965083518   11/01/2008     23:59:59   11/15/2008     23:59:59
# 4046403   576727230   12/13/2007     18:00:00   12/14/2007     23:59:59
# 4313564   570578651   07/01/2006     10:00:00   04/01/2007     23:59:59
# 3445603   597213125   05/01/2008     00:01:00   12/20/2008     23:59:59
# 3887411   375676496   06/01/2003     15:00:00   06/30/2004     23:59:59
# 3780568   228835328   05/01/2008     19:00:00   05/31/2008     23:59:59
# 3474079   506025924   01/01/2002     00:01:00   11/10/2007     23:59:59
# ...

# %%
# Get rid of troublesome '1016' date value
format_check = df_rape.CMPLNT_FR_DT.str.extract('^(\d{2})/(\d{2})/(\d{4})')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
# The '1016' value is troublesome

# %%
format_check[2].unique()
# Out:
# array(['2015', '2009', '2012', '2008', '2014', '2006', '2013', '2010',
#        '2002', '1993', '2011', '2007', '2003', '2000', '2005', '2004',
#        '2001', '1999', '1975', '1996', '1997', '1992', '1998', '1990',
#        '1994', '1988', '1995', '1989', '1978', '1991', '2016', '1984',
#        '1980', '1986', '1016', '1983', '2017', '1973', '1968', '1967',
#        '1976', '1981', '1987', '1977'], dtype=object)

# %%
df_rape['CMPLNT_FR_DT'] = df_rape['CMPLNT_FR_DT'].str.replace('1016','2016')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_rape.loc[df_rape['CMPLNT_FR_DT'].str.contains('1016')]
# Out:
# Empty DataFrame
# Columns: [CMPLNT_NUM, CMPLNT_FR_DT, CMPLNT_FR_TM, CMPLNT_TO_DT, CMPLNT_TO_TM, RPT_DT, KY_CD, OFNS_DESC, PD_CD, PD_DESC, CRM_ATPT_CPTD_CD, LAW_CAT_CD, JURIS_DESC, BORO_NM, ADDR_PCT_CD, LOC_OF_OCCUR_DESC, PREM_TYP_DESC, PARKS_NM, HADEVELOPT, X_COORD_CD, Y_COORD_CD, Latitude, Longitude, Lat_Lon]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# # Creation of datetime column

# %%
# Fix up date columns

# %%
# Fix up time columns, create series for them

# %%
print(type(CMPLNT_FR_TM_series[21]), type(CMPLNT_TO_TM_series[21]))
# Out:
# <class 'pandas._libs.tslib.Timestamp'> <class 'pandas._libs.tslib.Timestamp'>

# %%
CMPLNT_datetime_series_FR = df_rape['CMPLNT_FR_DT'] + ' ' + df_rape['CMPLNT_FR_TM']

# %%
CMPLNT_datetime_series_TO = df_rape['CMPLNT_TO_DT'] + ' ' + df_rape['CMPLNT_TO_TM']

# %%
print(type(CMPLNT_datetime_series_FR[21]), type(CMPLNT_datetime_series_TO[21]))
# Out:
# <class 'str'> <class 'str'>

# %%
CMPLNT_datetime_series_FR
# Out:
# 21         04/06/2015 12:00:00
# 252        12/01/2009 10:00:00
# 821        12/30/2015 18:00:00
# 1079       08/01/2015 00:01:00
# 1754       12/30/2015 03:04:00
# 2086       12/28/2015 18:00:00
# 2269       11/27/2015 20:00:00
# 2716       12/29/2015 15:30:00
# 3199       12/28/2015 20:00:00
# 3346       12/26/2015 02:30:00
# 4024       12/27/2015 21:30:00
# 4281       12/28/2015 02:40:00
# 5617       12/27/2015 01:00:00
# 5674       12/26/2015 23:30:00
# 5686       12/26/2015 23:00:00
# 5879       12/25/2015 06:00:00
# 5885       12/25/2015 02:00:00
# 5991       11/03/2015 12:00:00
# 6015       07/20/2015 12:00:00
# 6576       12/26/2015 09:25:00
# 6634       12/26/2015 05:00:00
# 7601       12/25/2015 04:00:00
# 7602       12/25/2015 02:30:00
# 7853       12/24/2015 17:30:00
# 7874       10/12/2015 00:01:00
# 8118       12/24/2015 18:00:00
# 8565       12/24/2015 03:25:00
# 9134       11/19/2015 23:00:00
# 10186      10/01/2015 12:00:00
# 10201      06/03/2015 01:00:00
# ...

# %%
CMPLNT_datetime_series_TO

# %%
# Timestamps for each of the columns

# %%
pd.to_datetime(CMPLNT_datetime_series_FR, infer_datetime_format=True)

# %%
pd.to_datetime(CMPLNT_datetime_series_TO, infer_datetime_format=True)

# %%
# OK, looks good, a series of Timestamps

# %%
type(pd.to_datetime(CMPLNT_datetime_series_FR, infer_datetime_format=True)[21])

# %%
type(CMPLNT_datetime_series_FR[21])
# Out:
# str

# %%
CMPLNT_datetime_series_TO
# Out:
# 21         04/10/2015 18:00:00
# 252        01/01/2010 10:00:00
# 821        12/30/2015 23:00:00
# 1079       12/30/2015 22:25:00
# 1754       12/30/2015 05:19:00
# 2086       12/28/2015 19:00:00
# 2269                       NaN
# 2716                       NaN
# 3199       12/28/2015 20:30:00
# 3346       12/26/2015 06:00:00
# 4024       12/27/2015 22:00:00
# 4281       12/28/2015 03:00:00
# 5617       12/27/2015 01:20:00
# 5674                       NaN
# 5686       12/27/2015 06:40:00
# 5879       12/25/2015 09:00:00
# 5885       12/25/2015 03:00:00
# 5991       11/03/2015 13:00:00
# 6015                       NaN
# 6576       12/26/2015 09:30:00
# 6634                       NaN
# 7601       12/25/2015 04:30:00
# 7602       12/25/2015 06:00:00
# 7853       12/25/2015 07:30:00
# 7874       10/12/2015 23:59:00
# 8118       12/24/2015 18:30:00
# 8565       12/24/2015 03:40:00
# 9134       11/19/2015 23:59:00
# 10186      10/31/2015 12:00:00
# 10201      06/03/2015 02:00:00
# ...

# %%
type(pd.to_datetime(CMPLNT_datetime_series_TO, infer_datetime_format=True)[21])
# Out:
# pandas._libs.tslib.Timestamp

# %%
# Successfully added a column with an incorrect date
# Try .loc with the proper to_datetime application?

df_rape['CMPLNT_FR_DATETIME'] = CMPLNT_datetime_series_FR
# df_rape = df_rape.assign(CMPLNT_FR_TM_series)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_rape['CMPLNT_TO_DATETIME'] = CMPLNT_datetime_series_TO
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_rape
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 21        340513307   04/06/2015     12:00:00   04/10/2015     18:00:00
# 252       198273659   12/01/2009     10:00:00   01/01/2010     10:00:00
# 821       591506102   12/30/2015     18:00:00   12/30/2015     23:00:00
# 1079      283109223   08/01/2015     00:01:00   12/30/2015     22:25:00
# 1754      361697946   12/30/2015     03:04:00   12/30/2015     05:19:00
# 2086      449252466   12/28/2015     18:00:00   12/28/2015     19:00:00
# 2269      841076951   11/27/2015     20:00:00          NaN          NaN
# 2716      462568423   12/29/2015     15:30:00          NaN          NaN
# 3199      632341905   12/28/2015     20:00:00   12/28/2015     20:30:00
# 3346      706551270   12/26/2015     02:30:00   12/26/2015     06:00:00
# 4024      994921451   12/27/2015     21:30:00   12/27/2015     22:00:00
# 4281      646084375   12/28/2015     02:40:00   12/28/2015     03:00:00
# ...

# %%
# Wait, what? Strings?

# %%
type(df_rape['CMPLNT_FR_DATETIME'][21])
# Out:
# str

# %%
type(df_rape['CMPLNT_TO_DATETIME'][21])
# Out:
# str

# %%
df_rape.dtypes
# Out:
# CMPLNT_NUM              int64
# CMPLNT_FR_DT           object
# CMPLNT_FR_TM           object
# CMPLNT_TO_DT           object
# CMPLNT_TO_TM           object
# RPT_DT                 object
# KY_CD                   int64
# OFNS_DESC              object
# PD_CD                 float64
# PD_DESC                object
# CRM_ATPT_CPTD_CD       object
# LAW_CAT_CD             object
# JURIS_DESC             object
# BORO_NM                object
# ADDR_PCT_CD           float64
# LOC_OF_OCCUR_DESC      object
# PREM_TYP_DESC          object
# PARKS_NM               object
# HADEVELOPT             object
# X_COORD_CD            float64
# Y_COORD_CD            float64
# Latitude              float64
# Longitude             float64
# Lat_Lon                object
# CMPLNT_FR_DATETIME     object
# CMPLNT_TO_DATETIME     object
# dtype: object

# %%
df_rape['CMPLNT_FR_DATETIME'] = pd.to_datetime(df_rape['CMPLNT_FR_DATETIME'], infer_datetime_format=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
type(pd.to_datetime(df_rape['CMPLNT_FR_DATETIME'], infer_datetime_format=True)[21])
# Out:
# pandas._libs.tslib.Timestamp

# %%
df_rape['RPT_DT'] = pd.to_datetime(df_rape['RPT_DT'], infer_datetime_format=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_rape['CMPLNT_TO_DATETIME'] = pd.to_datetime(df_rape['CMPLNT_TO_DATETIME'], infer_datetime_format=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
type(df_rape['CMPLNT_FR_DATETIME'][21])
# Out:
# pandas._libs.tslib.Timestamp

# %%
# Need to .loc the Timestamp types
df_rape['CRIME_DURATION'] = df_rape['CMPLNT_TO_DATETIME'] - df_rape['CMPLNT_FR_DATETIME']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_rape
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 21        340513307   04/06/2015     12:00:00   04/10/2015     18:00:00
# 252       198273659   12/01/2009     10:00:00   01/01/2010     10:00:00
# 821       591506102   12/30/2015     18:00:00   12/30/2015     23:00:00
# 1079      283109223   08/01/2015     00:01:00   12/30/2015     22:25:00
# 1754      361697946   12/30/2015     03:04:00   12/30/2015     05:19:00
# 2086      449252466   12/28/2015     18:00:00   12/28/2015     19:00:00
# 2269      841076951   11/27/2015     20:00:00          NaN          NaN
# 2716      462568423   12/29/2015     15:30:00          NaN          NaN
# 3199      632341905   12/28/2015     20:00:00   12/28/2015     20:30:00
# 3346      706551270   12/26/2015     02:30:00   12/26/2015     06:00:00
# 4024      994921451   12/27/2015     21:30:00   12/27/2015     22:00:00
# 4281      646084375   12/28/2015     02:40:00   12/28/2015     03:00:00
# ...

# %%
# Just some notes

data['hour'] = data['ts'].dt.hour
data['weekday'] = data['ts'].dt.weekday
data['weekday_name'] = data['ts'].dt.weekday_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-cec6dd8ef9a7> in <module>()
# ----> 1 data['hour'] = data['ts'].dt.hour
#       2 data['weekday'] = data['ts'].dt.weekday
#       3 data['weekday_name'] = data['ts'].dt.weekday_name
#
# NameError: name 'data' is not defined

# %%
df_rape.dtypes
# Out:
# CMPLNT_NUM                      int64
# CMPLNT_FR_DT                   object
# CMPLNT_FR_TM                   object
# CMPLNT_TO_DT                   object
# CMPLNT_TO_TM                   object
# RPT_DT                         object
# KY_CD                           int64
# OFNS_DESC                      object
# PD_CD                         float64
# PD_DESC                        object
# CRM_ATPT_CPTD_CD               object
# LAW_CAT_CD                     object
# JURIS_DESC                     object
# BORO_NM                        object
# ADDR_PCT_CD                   float64
# LOC_OF_OCCUR_DESC              object
# PREM_TYP_DESC                  object
# PARKS_NM                       object
# HADEVELOPT                     object
# X_COORD_CD                    float64
# Y_COORD_CD                    float64
# Latitude                      float64
# Longitude                     float64
# Lat_Lon                        object
# CMPLNT_FR_DATETIME     datetime64[ns]
# ...

# %%
df_rape['CRIME_DURATION']= df_rape['CMPLNT_TO_DATETIME'] - df_rape['CMPLNT_FR_DATETIME']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_rape
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 21        340513307   04/06/2015     12:00:00   04/10/2015     18:00:00
# 252       198273659   12/01/2009     10:00:00   01/01/2010     10:00:00
# 821       591506102   12/30/2015     18:00:00   12/30/2015     23:00:00
# 1079      283109223   08/01/2015     00:01:00   12/30/2015     22:25:00
# 1754      361697946   12/30/2015     03:04:00   12/30/2015     05:19:00
# 2086      449252466   12/28/2015     18:00:00   12/28/2015     19:00:00
# 2269      841076951   11/27/2015     20:00:00          NaN          NaN
# 2716      462568423   12/29/2015     15:30:00          NaN          NaN
# 3199      632341905   12/28/2015     20:00:00   12/28/2015     20:30:00
# 3346      706551270   12/26/2015     02:30:00   12/26/2015     06:00:00
# 4024      994921451   12/27/2015     21:30:00   12/27/2015     22:00:00
# 4281      646084375   12/28/2015     02:40:00   12/28/2015     03:00:00
# ...

# %%
# Locate the rows where something is true, target the column, replace with value on right side of the equal size

df_rape.loc[df_rape['CMPLNT_FR_DT'].isna(), 'CMPLNT_FR_DT'] = df_rape.loc[df_rape['CMPLNT_FR_DT'].isna(), #something
# Out:
#   File "<ipython-input-64-b7893a755dcc>", line 3
#     df_rape.loc[df_rape['CMPLNT_FR_DT'].isna(), 'CMPLNT_FR_DT'] = df_rape.loc[df_rape['CMPLNT_FR_DT'].isna()
#                                                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Time Investigation

# %%
# Delete this column
df_rape['CRIME_DURATION'].isnull().sum()
# Out:
# 3612

# %%
# Potential categorical variable with:
# * 0 - 30 minutes
# * 31 - 60 minutes
# 61 - 90 minutes
# 91 - 120 minutes
# 121 - 180 minutes
# 1 - 180 minutes
# ... find out if this is correlated to outcome variable

df_rape['CRIME_DURATION'].value_counts(ascending = False)
# Out:
# 0 days 00:30:00       1207
# 0 days 01:00:00       1180
# 0 days 00:15:00        543
# 0 days 00:10:00        540
# 0 days 02:00:00        478
# 0 days 00:05:00        422
# 0 days 00:20:00        320
# 0 days 03:00:00        275
# 0 days 00:00:00        274
# 0 days 01:30:00        256
# 0 days 04:00:00        214
# 0 days 00:45:00        186
# 0 days 05:00:00        144
# 0 days 02:30:00        126
# 0 days 00:40:00        120
# 0 days 07:00:00        105
# 0 days 06:00:00        100
# 0 days 00:25:00         96
# 0 days 23:58:00         91
# 0 days 03:30:00         84
# 0 days 08:00:00         71
# 0 days 00:50:00         58
# 0 days 09:00:00         56
# 0 days 10:00:00         54
# 0 days 00:35:00         53
# 0 days 05:30:00         51
# 0 days 04:30:00         50
# 0 days 01:15:00         46
# 30 days 23:58:00        43
# 0 days 06:30:00         40
#                       ...
# 44 days 08:00:00         1
# 4662 days 16:30:00       1
# 176 days 22:15:00        1
# ...

# %%
# 10 pm - 4 am are dangers hours- how does each hour bucket compare to 
# outcome variable? Change to % of total

df_rape['CMPLNT_FR_DATETIME'].dt.hour.value_counts(ascending = False)
# Out:
# 0     2429
# 12     995
# 23     920
# 2      878
# 1      845
# 3      805
# 22     762
# 4      742
# 20     709
# 15     708
# 16     671
# 21     641
# 18     619
# 8      617
# 5      523
# 17     514
# 19     491
# 14     485
# 9      427
# 13     399
# 6      395
# 10     395
# 11     377
# 7      326
# Name: CMPLNT_FR_DATETIME, dtype: int64

# %%
df_rape['CMPLNT_FR_DATETIME'].describe()
# Out:
# count                   16673
# unique                  15157
# top       2005-01-01 00:01:00
# freq                       23
# first     1967-01-01 12:00:00
# last      2017-12-29 03:30:00
# Name: CMPLNT_FR_DATETIME, dtype: object

# %%
df_rape['CRIME_DURATION'].dt.seconds.value_counts(ascending = False)
# Out:
# 3600.0     1317
# 1800.0     1270
# 0.0        1169
# 86280.0     679
# 7200.0      568
# 900.0       554
# 600.0       550
# 300.0       424
# 10800.0     353
# 1200.0      328
# 14400.0     281
# 5400.0      276
# 18000.0     198
# 2700.0      192
# 25200.0     160
# 21600.0     152
# 9000.0      145
# 2400.0      125
# 28800.0     124
# 1500.0       98
# 12600.0      95
# 86340.0      95
# 32400.0      89
# 36000.0      77
# 54000.0      73
# 43200.0      70
# 39600.0      69
# 50400.0      67
# 46800.0      61
# 19800.0      61
#            ...
# 24060.0       1
# 16440.0       1
# 26160.0       1
# 38400.0       1
# 75780.0       1
# 84000.0       1
# 79920.0       1
# 60360.0       1
# 46020.0       1
# 35040.0       1
# 37740.0       1
# 17820.0       1
# 33540.0       1
# 23640.0       1
# 45900.0       1
# 58200.0       1
# 83640.0       1
# 28080.0       1
# 34560.0       1
# 52080.0       1
# 33720.0       1
# 33660.0       1
# 50940.0       1
# 62340.0       1
# ...

# %%
df_rape['CRIME_DURATION'].dt.seconds
# Out:
# 21         21600.0
# 252            0.0
# 821        18000.0
# 1079       80640.0
# 1754        8100.0
# 2086        3600.0
# 2269           NaN
# 2716           NaN
# 3199        1800.0
# 3346       12600.0
# 4024        1800.0
# 4281        1200.0
# 5617        1200.0
# 5674           NaN
# 5686       27600.0
# 5879       10800.0
# 5885        3600.0
# 5991        3600.0
# 6015           NaN
# 6576         300.0
# 6634           NaN
# 7601        1800.0
# 7602       12600.0
# 7853       50400.0
# 7874       86280.0
# 8118        1800.0
# 8565         900.0
# 9134        3540.0
# 10186          0.0
# 10201       3600.0
#             ...
# 6040310    86280.0
# 6040425        NaN
# 6040838     6300.0
# 6041810     1200.0
# 6042022        NaN
# 6042246     7200.0
# 6042481        NaN
# 6043297     1200.0
# 6043679     1800.0
# 6043850    86280.0
# 6043853        0.0
# 6044850     2700.0
# 6045256    75600.0
# 6045257     1800.0
# 6045948     1800.0
# 6045964     4500.0
# ...

# %%
df_rape['DURATION_IN_SECONDS'] = df_rape['CRIME_DURATION'].dt.seconds
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_rape['DURATION_IN_SECONDS']
# Out:
# 21         21600.0
# 252            0.0
# 821        18000.0
# 1079       80640.0
# 1754        8100.0
# 2086        3600.0
# 2269           NaN
# 2716           NaN
# 3199        1800.0
# 3346       12600.0
# 4024        1800.0
# 4281        1200.0
# 5617        1200.0
# 5674           NaN
# 5686       27600.0
# 5879       10800.0
# 5885        3600.0
# 5991        3600.0
# 6015           NaN
# 6576         300.0
# 6634           NaN
# 7601        1800.0
# 7602       12600.0
# 7853       50400.0
# 7874       86280.0
# 8118        1800.0
# 8565         900.0
# 9134        3540.0
# 10186          0.0
# 10201       3600.0
#             ...
# 6040310    86280.0
# 6040425        NaN
# 6040838     6300.0
# 6041810     1200.0
# 6042022        NaN
# 6042246     7200.0
# 6042481        NaN
# 6043297     1200.0
# 6043679     1800.0
# 6043850    86280.0
# 6043853        0.0
# 6044850     2700.0
# 6045256    75600.0
# 6045257     1800.0
# 6045948     1800.0
# 6045964     4500.0
# ...

# %%
df_rape['DURATION_IN_MINUTES'] = df_rape['DURATION_IN_SECONDS']/60
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_rape['DURATION_IN_MINUTES'].value_counts(ascending = False)
# Out:
# 60.000000      1317
# 30.000000      1270
# 0.000000       1169
# 1438.000000     679
# 120.000000      568
# 15.000000       554
# 10.000000       550
# 5.000000        424
# 180.000000      353
# 20.000000       328
# 240.000000      281
# 90.000000       276
# 300.000000      198
# 45.000000       192
# 420.000000      160
# 360.000000      152
# 150.000000      145
# 40.000000       125
# 480.000000      124
# 25.000000        98
# 210.000000       95
# 1439.000000      95
# 540.000000       89
# 600.000000       77
# 900.000000       73
# 720.000000       70
# 660.000000       69
# 840.000000       67
# 780.000000       61
# 330.000000       61
#                ...
# 298.000000        1
# 187.000000        1
# 697.000000        1
# 868.000000        1
# 924.000000        1
# 349.000000        1
# 763.000000        1
# 431.000000        1
# 116.000000        1
# 322.000000        1
# 560.000000        1
# 597.000000        1
# 479.983333        1
# 242.000000        1
# ...

# %%
df_rape['DURATION_IN_HOURS'] = df_rape['DURATION_IN_SECONDS']/3600
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Again, may put in buckets for categorical values

df_rape['DURATION_IN_HOURS'].value_counts(ascending = False)
# Out:
# 1.000000     1317
# 0.500000     1270
# 0.000000     1169
# 23.966667     679
# 2.000000      568
# 0.250000      554
# 0.166667      550
# 0.083333      424
# 3.000000      353
# 0.333333      328
# 4.000000      281
# 1.500000      276
# 5.000000      198
# 0.750000      192
# 7.000000      160
# 6.000000      152
# 2.500000      145
# 0.666667      125
# 8.000000      124
# 0.416667       98
# 23.983333      95
# 3.500000       95
# 9.000000       89
# 10.000000      77
# 15.000000      73
# 12.000000      70
# 11.000000      69
# 14.000000      67
# 13.000000      61
# 5.500000       61
#              ...
# 13.050000       1
# 23.883333       1
# 10.483333       1
# 20.016667       1
# 23.233333       1
# 16.516667       1
# 13.233333       1
# 14.433333       1
# 14.666667       1
# 22.966667       1
# 15.416667       1
# 7.300000        1
# 5.316667        1
# 3.383333        1
# 13.466667       1
# 2.966667        1
# 8.816667        1
# 17.616667       1
# 10.283333       1
# ...

# %%
df_rape
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 21        340513307   04/06/2015     12:00:00   04/10/2015     18:00:00
# 252       198273659   12/01/2009     10:00:00   01/01/2010     10:00:00
# 821       591506102   12/30/2015     18:00:00   12/30/2015     23:00:00
# 1079      283109223   08/01/2015     00:01:00   12/30/2015     22:25:00
# 1754      361697946   12/30/2015     03:04:00   12/30/2015     05:19:00
# 2086      449252466   12/28/2015     18:00:00   12/28/2015     19:00:00
# 2269      841076951   11/27/2015     20:00:00          NaN          NaN
# 2716      462568423   12/29/2015     15:30:00          NaN          NaN
# 3199      632341905   12/28/2015     20:00:00   12/28/2015     20:30:00
# 3346      706551270   12/26/2015     02:30:00   12/26/2015     06:00:00
# 4024      994921451   12/27/2015     21:30:00   12/27/2015     22:00:00
# 4281      646084375   12/28/2015     02:40:00   12/28/2015     03:00:00
# ...

# %%
# Convert to datetime for more calculations
type(df_rape['RPT_DT'][21])
# Out:
# pandas._libs.tslib.Timestamp

# %%
df_rape['RPT_DT']
# Out:
# 21        2015-12-21
# 252       2015-12-07
# 821       2015-12-31
# 1079      2015-12-31
# 1754      2015-12-30
# 2086      2015-12-30
# 2269      2015-12-30
# 2716      2015-12-29
# 3199      2015-12-29
# 3346      2015-12-29
# 4024      2015-12-28
# 4281      2015-12-28
# 5617      2015-12-27
# 5674      2015-12-27
# 5686      2015-12-27
# 5879      2015-12-27
# 5885      2015-12-27
# 5991      2015-12-27
# 6015      2015-12-27
# 6576      2015-12-26
# 6634      2015-12-26
# 7601      2015-12-25
# 7602      2015-12-25
# 7853      2015-12-25
# 7874      2015-12-19
# 8118      2015-12-24
# 8565      2015-12-24
# 9134      2015-12-16
# 10186     2015-12-23
# 10201     2015-12-23
#              ...
# 6040310   2017-01-08
# 6040425   2017-01-07
# 6040838   2017-01-07
# 6041810   2017-01-06
# 6042022   2017-01-06
# 6042246   2017-01-06
# 6042481   2017-01-06
# 6043297   2017-01-05
# 6043679   2017-01-05
# 6043850   2017-01-05
# 6043853   2017-01-05
# 6044850   2017-01-04
# ...

# %%
# Difference between report date and beginning of attemped/completed crime
df_rape['TIME_TO_REPORT'] = df_rape['RPT_DT'] - df_rape['CMPLNT_FR_DATETIME']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_rape['TIME_TO_REPORT'].isnull().sum()
# Out:
# 0

# %%
# Might 'bucketize' this- also, investigate relationship 
# to outcome variable
df_rape['TIME_TO_REPORT'].value_counts(ascending = False)
# Out:
# -1 days +21:00:00     275
# -1 days +22:00:00     264
# -1 days +20:00:00     239
# -1 days +23:00:00     210
# 0 days 01:00:00       182
# 0 days 02:00:00       170
# -1 days +19:00:00     169
# -1 days +23:59:00     137
# 0 days 04:00:00       128
# -1 days +18:00:00     126
# 0 days 03:00:00       125
# -1 days +23:30:00     119
# -1 days +19:30:00     114
# -1 days +21:30:00     113
# -1 days +20:30:00     105
# -1 days +22:30:00     101
# -1 days +12:00:00      97
# -1 days +18:30:00      92
# 0 days 00:30:00        83
# 0 days 05:00:00        82
# -1 days +16:00:00      81
# 0 days 06:00:00        80
# -1 days +14:00:00      77
# 0 days 00:00:00        77
# 0 days 01:30:00        74
# -1 days +11:00:00      73
# -1 days +10:00:00      73
# 0 days 02:30:00        72
# -1 days +08:00:00      71
# 0 days 07:00:00        70
#                      ...
# 800 days 04:00:00       1
# 0 days 03:55:00         1
# 365 days 06:00:00       1
# 152 days 06:30:00       1
# ...

# %%
df_rape['LAW_CAT_CD'].value_counts(ascending = False)
# Out:
# FELONY    16673
# Name: LAW_CAT_CD, dtype: int64

# %%
# This is meaningless, almost entirely police dept
df_rape['JURIS_DESC'].value_counts(ascending = False)
# Out:
# N.Y. POLICE DEPT       14728
# N.Y. HOUSING POLICE     1824
# N.Y. TRANSIT POLICE       41
# POLICE DEPT NYC           16
# OTHER                     15
# PORT AUTHORITY            15
# HEALTH & HOSP CORP        14
# DEPT OF CORRECTIONS        7
# N.Y. STATE POLICE          3
# NYC PARKS                  3
# METRO NORTH                3
# AMTRACK                    2
# N.Y. STATE PARKS           1
# U.S. PARK POLICE           1
# Name: JURIS_DESC, dtype: int64

# %%
# This is imbalance
df_rape['BORO_NM'].value_counts(ascending = False)
# Out:
# BROOKLYN         5002
# QUEENS           3802
# BRONX            3692
# MANHATTAN        3530
# STATEN ISLAND     643
# Name: BORO_NM, dtype: int64

# %%
# Make the above per capita
# Populations in 2017:
# Manhattan: 1.665 million
# Brooklyn: 2.649 million
# Queens: 2.359 million
# Bronx: 1.471 million
# Staten Island: 479,458

# %%
# Which years the crimes were committed, in case I need to think about
# subsets for an accurate analysis
# Looks like cutting data to 2006 - 2018 is more meaningful
df_rape['CMPLNT_FR_DATETIME'].dt.year.value_counts(ascending = False)
# Out:
# 2006    1539
# 2011    1407
# 2012    1394
# 2010    1378
# 2013    1338
# 2015    1333
# 2007    1276
# 2016    1268
# 2008    1265
# 2014    1258
# 2009    1190
# 2017    1160
# 2005     316
# 2004     117
# 2003     102
# 2001      66
# 2002      64
# 2000      44
# 1999      44
# 1998      30
# 1997      15
# 1993      14
# 1996      12
# 1994       7
# 1995       5
# 1992       4
# 1991       3
# 1975       2
# 1989       2
# 1984       2
# 1983       2
# 1988       2
# 1990       2
# 1978       2
# 1986       2
# 1981       1
# 1967       1
# 1987       1
# 1980       1
# 1977       1
# 1976       1
# 1973       1
# 1968       1
# Name: CMPLNT_FR_DATETIME, dtype: int64

# %%
df_rape['CMPLNT_FR_DATETIME'].dt.year.value_counts()
# Out:
# 2006    1539
# 2011    1407
# 2012    1394
# 2010    1378
# 2013    1338
# 2015    1333
# 2007    1276
# 2016    1268
# 2008    1265
# 2014    1258
# 2009    1190
# 2017    1160
# 2005     316
# 2004     117
# 2003     102
# 2001      66
# 2002      64
# 2000      44
# 1999      44
# 1998      30
# 1997      15
# 1993      14
# 1996      12
# 1994       7
# 1995       5
# 1992       4
# 1991       3
# 1975       2
# 1989       2
# 1984       2
# 1983       2
# 1988       2
# 1990       2
# 1978       2
# 1986       2
# 1981       1
# 1967       1
# 1987       1
# 1980       1
# 1977       1
# 1976       1
# 1973       1
# 1968       1
# Name: CMPLNT_FR_DATETIME, dtype: int64

# %%
df_rape.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon', 'CMPLNT_FR_DATETIME', 'CMPLNT_TO_DATETIME', 'CRIME_DURATION',
#        'DURATION_IN_SECONDS', 'DURATION_IN_MINUTES', 'DURATION_IN_HOURS',
#        'TIME_TO_REPORT'],
#       dtype='object')

# %%
df_rape['KY_CD'].value_counts()
# Out:
# 104    16673
# Name: KY_CD, dtype: int64

# %%
df_rape['OFNS_DESC'].value_counts()
# Out:
# RAPE    16673
# Name: OFNS_DESC, dtype: int64

# %%
df_rape['PD_CD'].value_counts()
# Out:
# 157.0    10801
# 153.0     2242
# 159.0     1819
# 155.0     1811
# Name: PD_CD, dtype: int64

# %%
df_rape['PD_DESC'].value_counts()
# Out:
# RAPE 1            10801
# RAPE 3             2242
# RAPE 1,ATTEMPT     1819
# RAPE 2             1811
# Name: PD_DESC, dtype: int64

# %%
ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
       'HADEVELOPT'

# %%
df_rape['ADDR_PCT_CD'].value_counts().shape
# Out:
# (77,)

# %%
df_rape['ADDR_PCT_CD'].value_counts()
# Out:
# 75.0     701
# 115.0    431
# 43.0     431
# 120.0    426
# 47.0     425
# 67.0     417
# 73.0     412
# 44.0     411
# 46.0     386
# 83.0     379
# 110.0    370
# 103.0    365
# 40.0     361
# 32.0     341
# 105.0    338
# 42.0     326
# 52.0     324
# 114.0    319
# 79.0     318
# 113.0    316
# 48.0     302
# 70.0     283
# 25.0     264
# 102.0    260
# 23.0     256
# 77.0     250
# 34.0     229
# 30.0     229
# 81.0     228
# 49.0     227
#         ...
# 18.0     150
# 14.0     147
# 19.0     139
# 24.0     131
# 66.0     130
# 63.0     129
# 26.0     129
# 61.0     128
# 62.0     128
# 7.0      127
# 10.0     123
# 50.0     121
# 6.0      121
# 122.0    117
# 1.0      108
# 88.0     107
# 68.0     106
# 17.0      99
# 20.0      95
# 94.0      87
# 5.0       86
# 78.0      79
# 100.0     79
# 112.0     77
# 121.0     66
# 76.0      65
# 84.0      59
# 111.0     53
# 123.0     34
# 22.0      25
# Name: ADDR_PCT_CD, Length: 77, dtype: int64

# %%
# Discard
df_rape['LOC_OF_OCCUR_DESC'].value_counts()
# Out:
# INSIDE         14003
# FRONT OF         780
# REAR OF          218
# OPPOSITE OF      117
# Name: LOC_OF_OCCUR_DESC, dtype: int64

# %%
# Get_dummies on first five
df_rape['PREM_TYP_DESC'].value_counts().shape
# Out:
# (55,)

# %%
# Think about PCA
df_rape['PREM_TYP_DESC'].value_counts()
# Out:
# RESIDENCE - APT. HOUSE          8501
# RESIDENCE-HOUSE                 3094
# RESIDENCE - PUBLIC HOUSING      1782
# STREET                          1029
# HOTEL/MOTEL                      657
# OTHER                            344
# PARK/PLAYGROUND                  262
# HOSPITAL                         126
# BAR/NIGHT CLUB                   125
# COMMERCIAL BUILDING              103
# PUBLIC SCHOOL                     71
# OPEN AREAS (OPEN LOTS)            52
# PUBLIC BUILDING                   40
# TRANSIT - NYC SUBWAY              38
# RESTAURANT/DINER                  37
# PARKING LOT/GARAGE (PUBLIC)       33
# PARKING LOT/GARAGE (PRIVATE)      30
# ABANDONED BUILDING                27
# GROCERY/BODEGA                    27
# CHURCH                            24
# STORE UNCLASSIFIED                15
# TAXI (YELLOW LICENSED)            15
# SMALL MERCHANT                    12
# FAST FOOD                         10
# TAXI (LIVERY LICENSED)            10
# ...

# %%
'PARKS_NM',
       'HADEVELOPT'

# %%
df_rape['PARKS_NM'].value_counts().shape
# Out:
# (56,)

# %%
# discard
df_rape['PARKS_NM'].value_counts()
# Out:
# CENTRAL PARK                                                           10
# RIVERSIDE PARK                                                          5
# PROSPECT PARK                                                           5
# CONEY ISLAND BEACH & BOARDWALK                                          4
# RUFUS KING PARK                                                         3
# VAN CORTLANDT PARK                                                      3
# BRONX PARK                                                              3
# ROCKAWAY BEACH AND BOARDWALK                                            2
# SOUNDVIEW PARK                                                          2
# PELHAM BAY PARK                                                         2
# TREMONT PARK                                                            2
# RED HOOK RECREATION AREA                                                2
# EAST RIVER PARK                                                         2
# ...

# %%
df_rape['HADEVELOPT'].value_counts().shape
# Out:
# (201,)

# %%
#discard
df_rape['HADEVELOPT'].value_counts()
# Out:
# CASTLE HILL                                    28
# VAN DYKE I                                     28
# BUTLER                                         26
# PINK                                           22
# TOMPKINS                                       22
# GRANT                                          20
# SMITH                                          18
# BROWNSVILLE                                    17
# BARUCH                                         16
# LINDEN                                         16
# MARCY                                          16
# MANHATTANVILLE                                 15
# BOULEVARD                                      15
# TILDEN                                         15
# BUSHWICK                                       15
# RANGEL                                         14
# WHITMAN                                        14
# CYPRESS HILLS                                  14
# FARRAGUT                                       14
# ...
